# %%
import pandas as pd
import numpy as np

# %%
cd
# Out:
# C:\Users\Proxy1

# %%
hd=pd.read_csv('coe_python/day-7/Mall_Customers.csv')
hd
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
hd.info
hd.shape
# Out:
# (200, 5)

# %%
hd.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
hd.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
hd['Age']
# Out:
# 0      19
# 1      21
# 2      20
# 3      23
# 4      31
#        ..
# 195    35
# 196    45
# 197    32
# 198    32
# 199    30
# Name: Age, Length: 200, dtype: int64

# %%
ex=hd.iloc[1:10,2:5]
ex
# Out:
#    Age  Annual Income (k$)  Spending Score (1-100)
# 1   21                  15                      81
# 2   20                  16                       6
# 3   23                  16                      77
# 4   31                  17                      40
# 5   22                  17                      76
# 6   35                  18                       6
# 7   23                  18                      94
# 8   64                  19                       3
# 9   30                  19                      72

# %%
hd['Age'].unique()
# Out:
# array([19, 21, 20, 23, 31, 22, 35, 64, 30, 67, 58, 24, 37, 52, 25, 46, 54,
#        29, 45, 40, 60, 53, 18, 49, 42, 36, 65, 48, 50, 27, 33, 59, 47, 51,
#        69, 70, 63, 43, 68, 32, 26, 57, 38, 55, 34, 66, 39, 44, 28, 56, 41],
#       dtype=int64)

# %%
duplicate=hd.duplicated().sum()
duplicate
# Out:
# 0

# %%
hd.drop_duplicates()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
hd.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
hd.rename(columns={'Age':'age'})
# Out:
#      CustomerID  Gender  age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
#stats of the data
hd['Age'].mean()
# Out:
# 38.85

# %%
hd['Age'].median()
# Out:
# 36.0

# %%
hd['Age'].std()
# Out:
# 13.969007331558883

# %%
hd['Age'].mode()
# Out:
# 0    32
# Name: Age, dtype: int64

# %%
hd.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df=pd.read_csv('coe_python/day-7/Mall_Customers_null1.csv')
df
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                15.0                    39.0
# 1             2    Male  21.0                15.0                    81.0
# 2             3  Female  20.0                16.0                     6.0
# 3             4  Female  23.0                16.0                    77.0
# 4             5  Female  31.0                17.0                    40.0
# ..          ...     ...   ...                 ...                     ...
# 195         196  Female  35.0               120.0                    79.0
# 196         197  Female  45.0               126.0                    28.0
# 197         198    Male  32.0               126.0                    74.0
# 198         199    Male  32.0                 NaN                    18.0
# 199         200    Male  30.0               137.0                    83.0
#
# [200 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       3
# Annual Income (k$)        4
# Spending Score (1-100)    2
# dtype: int64

# %%
df.fillna('0')
# Out:
#      CustomerID  Gender   Age Annual Income (k$) Spending Score (1-100)
# 0             1    Male  19.0               15.0                   39.0
# 1             2    Male  21.0               15.0                   81.0
# 2             3  Female  20.0               16.0                    6.0
# 3             4  Female  23.0               16.0                   77.0
# 4             5  Female  31.0               17.0                   40.0
# ..          ...     ...   ...                ...                    ...
# 195         196  Female  35.0              120.0                   79.0
# 196         197  Female  45.0              126.0                   28.0
# 197         198    Male  32.0              126.0                   74.0
# 198         199    Male  32.0                  0                   18.0
# 199         200    Male  30.0              137.0                   83.0
#
# [200 rows x 5 columns]

# %%
df.dtypes
# Out:
# CustomerID                  int64
# Gender                     object
# Age                       float64
# Annual Income (k$)        float64
# Spending Score (1-100)    float64
# dtype: object

# %%
df.to_numpy()
# Out:
# array([[1, 'Male', 19.0, 15.0, 39.0],
#        [2, 'Male', 21.0, 15.0, 81.0],
#        [3, 'Female', 20.0, 16.0, 6.0],
#        [4, 'Female', 23.0, 16.0, 77.0],
#        [5, 'Female', 31.0, 17.0, 40.0],
#        [6, 'Female', 22.0, 17.0, 76.0],
#        [7, 'Female', 35.0, 18.0, 6.0],
#        [8, 'Female', 23.0, 18.0, 94.0],
#        [9, 'Male', 64.0, 19.0, 3.0],
#        [10, 'Female', 30.0, 19.0, 72.0],
#        [11, 'Male', 67.0, 19.0, 14.0],
#        [12, 'Female', 35.0, 19.0, 99.0],
#        [13, 'Female', 58.0, 20.0, 15.0],
#        [14, 'Female', 24.0, 20.0, 77.0],
#        [15, 'Male', 37.0, 20.0, 13.0],
#        [16, 'Male', 22.0, 20.0, 79.0],
#        [17, 'Female', 35.0, 21.0, 35.0],
#        [18, 'Male', 20.0, 21.0, 66.0],
#        [19, 'Male', 52.0, 23.0, 29.0],
#        [20, 'Female', nan, 23.0, 98.0],
#        [21, 'Male', 35.0, 24.0, 35.0],
#        [22, 'Male', 25.0, 24.0, 73.0],
#        [23, 'Female', 46.0, 25.0, 5.0],
#        [24, 'Male', 31.0, 25.0, 73.0],
# ...

# %%
hd.sort_values(by='Age',ascending=False)
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 70           71    Male   70                  49                      55
# 60           61    Male   70                  46                      56
# 57           58    Male   69                  44                      46
# 90           91  Female   68                  59                      55
# 67           68  Female   68                  48                      48
# ..          ...     ...  ...                 ...                     ...
# 0             1    Male   19                  15                      39
# 33           34    Male   18                  33                      92
# 65           66    Male   18                  48                      59
# 91           92    Male   18                  59                      41
# 114         115  Female   18                  65                      48
#
# [200 rows x 5 columns]

# %%
hd['Annual Income (k$)'].mean()
# Out:
# 60.56
