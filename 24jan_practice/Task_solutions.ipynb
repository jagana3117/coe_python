# %%
'''Task To Do:
sales analysis:use line plot to track monthly sales and histogram for order quantity distribution.
customer demographics:visulasise age distribution(histogram) and spending patterns(sactter plot).
school performance:comapre students marks across subjects (bar chart) and identify outliers(box plot)

# %%
 import pandas as pd
 import matplotlib.pyplot as plt
 data=pd.read_csv('monthly_sales.csv')
plt.figure(figsize=(17,5))
plt.plot(data['Month'],data['Sales '],marker='*',linestyle='dotted',linewidth=3)
plt.title('monthly sales line plot')
plt.xlabel('month')
plt.ylabel('sales')
plt.show()

# %%
data = pd.read_csv('eaxmple_hist.csv')
plt.figure(figsize=(10, 5))
plt.hist(data['OrderQuantity'], bins=7, color='green', edgecolor='black') 
plt.title('Order Quantity Distribution')
plt.xlabel('Order Quantity')
plt.ylabel('Frequency')

plt.show()

# %%
df=pd.read_csv('age_spending.csv')
plt.hist(df['Age'],bins=6,color='blue',edgecolor='black')
plt.title('age distribution histogram')
plt.xlabel('Age')
plt.ylabel('frequency')
plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'Spending '], dtype='object')

# %%
plt.figure(figsize=(17,5))
plt.scatter(df['Age'],df['Spending '],marker='*')
plt.title('monthly sales line plot')
plt.xlabel('month')
plt.ylabel('sales')
plt.show()

# %%
std=pd.read_csv('student_marks.csv')
y=std[['Math','Science','English','History','Art']].mean()
y.plot(kind='bar', color=['skyblue', 'lightgreen', 'salmon', 'gold', 'violet'])
plt.title("student marks")
plt.xlabel('students')
plt.ylabel('subjects')
plt.show()

# %%
plt.figure(figsize=(10, 6))
df[['Math', 'Science', 'English', 'History', 'Art']].boxplot()
plt.title('Box Plot: Marks Distribution Across Subjects')
plt.ylabel('Marks', fontsize=12)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
